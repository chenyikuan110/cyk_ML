# %%
import wave, numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile
import sounddevice as sd
from os import listdir
from os.path import isfile, join

# %%
i = 0

# %%
wavpath = "./audio_set/gunshot/"
wavfiles = [f for f in listdir(wavpath) if isfile(join(wavpath, f))]
print(wavfiles)

file_name = "./audio_set/gunshot/"+wavfiles[i]

fs,x_wave = wavfile.read(file_name)
print(fs)
#interval = np.genfromtxt(txt_name, delimiter='\t')
sd.play(x_wave,fs,blocking=True)
print(x_wave.shape)
two = 1
if(x_wave.shape[0]/fs > 10):
    two = 2
plt.minorticks_on()
plt.rcParams["figure.figsize"] = [18,3]
plt.plot(np.linspace(start=0,stop=int(x_wave.shape[0]/fs/two),num=int(x_wave.shape[0]/two)),x_wave[:int(x_wave.shape[0]/two),0])
plt.show()

if(two == 2):
    plt.minorticks_on()
    plt.plot(np.linspace(start=int(x_wave.shape[0]/fs/two),stop=int(x_wave.shape[0]/fs),num=int(x_wave.shape[0]/two)),x_wave[int(x_wave.shape[0]/two):,0])
    plt.show()
# Out:
# ['shot_00.wav', 'shot_01.wav', 'shot_02.wav', 'shot_03.wav', 'shot_04.wav', 'shot_05.wav', 'shot_06.wav', 'shot_07.wav', 'shot_08.wav', 'shot_09.wav', 'shot_10.wav', 'shot_11.wav', 'shot_12.wav', 'shot_13.wav', 'shot_14.wav', 'shot_15.wav', 'shot_16.wav', 'shot_17.wav', 'shot_18.wav', 'shot_19.wav']
# 44100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-608850a76f10> in <module>()
#       8 print(fs)
#       9 #interval = np.genfromtxt(txt_name, delimiter='\t')
# ---> 10 sd.play(x_wave,fs,blocking=True)
#      11 print(x_wave.shape)
#      12 two = 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\sounddevice.py in play(data, samplerate, mapping, blocking, loop, **kwargs)
#     144                      ctx.output_dtype, callback, blocking,
#     145                      prime_output_buffers_using_stream_callback=False,
# ...

# %%
txtpath = "./audio_set/gunshot/gun_text/"
print(wavfiles," ",i)
txt_name = txtpath+wavfiles[i]+".txt"
f = open(txt_name,'w')
f.write('')
f.close()
# Out:
# ['shot_00.wav', 'shot_01.wav', 'shot_02.wav', 'shot_03.wav', 'shot_04.wav', 'shot_05.wav', 'shot_06.wav', 'shot_07.wav', 'shot_08.wav', 'shot_09.wav', 'shot_10.wav', 'shot_11.wav', 'shot_12.wav', 'shot_13.wav', 'shot_14.wav', 'shot_15.wav', 'shot_16.wav', 'shot_17.wav', 'shot_18.wav', 'shot_19.wav']   18

# %%
i += 1
print(i)
# Out:
# 19

# %%
    f, t, Sxx = signal.spectrogram(x_wave[:,0], fs,window=("hann"))
        


    #Sxx /= Sxx.max()
    #Sxx = -np.log(Sxx+1e-9)
    Sxx /= Sxx.max()
    labels = np.zeros(Sxx.shape[1])
    print("Sxx.shape=",Sxx.shape)
    
    print("\nRaw spectrogram")
    plt.pcolormesh(t, f, np.log(Sxx+1e-8))
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    plt.show()
# Out:
# Sxx.shape= (129, 150)
#
# Raw spectrogram
